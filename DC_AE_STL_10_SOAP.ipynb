# %%
# !pip install pytorch-optimizer
# Out:
# Collecting pytorch-optimizer
#   Downloading pytorch_optimizer-3.3.0-py3-none-any.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.9/62.9 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>1.24.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-optimizer) (1.26.4)
# Requirement already satisfied: torch>=1.10 in /usr/local/lib/python3.10/dist-packages (from pytorch-optimizer) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pytorch-optimizer) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pytorch-optimizer) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pytorch-optimizer) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pytorch-optimizer) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pytorch-optimizer) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10->pytorch-optimizer) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10->pytorch-optimizer) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10->pytorch-optimizer) (3.0.2)
# Downloading pytorch_optimizer-3.3.0-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.0/207.0 kB 8.4 MB/s eta 0:00:00
# Installing collected packages: pytorch-optimizer
# Successfully installed pytorch-optimizer-3.3.0

# %%
import torch

# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

def space_to_channel(x, scale):
  """
  Space-to-channel operation (non-parametric shortcut for downsample block).

  Args:
    x: Input tensor of shape (B, C, H, W).
    scale: Downsampling scale.

  Returns:
    Output tensor of shape (B, C * scale, H / scale, W / scale).
  """
  B, C, H, W = x.size()
  return x.view(B, C, H // scale, scale, W // scale, scale).permute(0, 1, 3, 5, 2, 4).reshape(B, C * scale, scale, H // scale, W // scale).mean(dim=2)

def channel_to_space(x, scale):
  """
  Channel-to-space operation (non-parametric shortcut for upsample block).

  Args:
    x: Input tensor of shape (B, C * scale, H / scale, W / scale).
    scale: Upsampling scale.

  Returns:
    Output tensor of shape (B, C, H, W).
  """
  B, C, H, W = x.size()
  x =  x.view(B, C // (scale * scale), scale, scale, H, W).permute(0, 1, 4, 2, 5, 3).reshape(B, C // (scale * scale), H * scale, W * scale)
  return torch.cat((x, x), dim=1)

class ResidualBlock(nn.Module):
  """
  Residual block used in both encoder and decoder.
  """
  def __init__(self, in_channels, out_channels, is_middle=False):
    super().__init__()
    self.is_middle = is_middle
    # Calculate num_groups based on in_channels to ensure divisibility
    num_groups = min(32, in_channels)
    self.conv1 = nn.Sequential(
        nn.GroupNorm(num_groups, in_channels), # Use calculated num_groups
        nn.SiLU(),
        nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
        nn.Dropout(0.01)
    )
    # Calculate num_groups based on out_channels to ensure divisibility
    num_groups = min(32, out_channels)
    self.conv2 = nn.Sequential(
        nn.GroupNorm(num_groups, out_channels), # Use calculated num_groups
        nn.SiLU(),
        nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
        nn.Dropout(0.01)
    )
    if is_middle:
        self.conv_shortcut = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    self.initialize_weights()

  def initialize_weights(self):
    # Initialize conv layers with kaiming_normal
    for m in self.modules():
        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.GroupNorm):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0)
    # Zero-initialize the last conv layer in each residual block
    nn.init.constant_(self.conv2[-2].weight, 0)
    if self.is_middle:
        nn.init.constant_(self.conv_shortcut.weight, 0)

  def forward(self, x):
    identity = x
    x = self.conv1(x)
    x = self.conv2(x)
    if self.is_middle:
      identity = self.conv_shortcut(identity)
      x = x + identity
    return x

class DownsampleResidualBlock(nn.Module):
  """
  Residual block used in both encoder and decoder.
  """
  def __init__(self, in_channels, out_channels, is_middle=False):
    super().__init__()
    self.is_middle = is_middle
    # Calculate num_groups based on in_channels to ensure divisibility
    num_groups = min(32, in_channels)
    self.conv1 = nn.Sequential(
        nn.GroupNorm(num_groups, in_channels), # Use calculated num_groups
        nn.SiLU(),
        nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1, stride=2),
        nn.Dropout(0.01)
    )
    # Calculate num_groups based on out_channels to ensure divisibility
    num_groups = min(32, out_channels)
    self.conv2 = nn.Sequential(
        nn.GroupNorm(num_groups, out_channels), # Use calculated num_groups
        nn.SiLU(),
        nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1, stride=2),
        nn.Dropout(0.01)
    )
    if is_middle:
        self.conv_shortcut = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    self.initialize_weights()

  def initialize_weights(self):
    # Initialize conv layers with kaiming_normal
    for m in self.modules():
        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.GroupNorm):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0)
    # Zero-initialize the last conv layer in each residual block
    nn.init.constant_(self.conv2[-2].weight, 0)
    if self.is_middle:
        nn.init.constant_(self.conv_shortcut.weight, 0)

  def forward(self, x):
    identity = x
    x = self.conv1(x)
    x = self.conv2(x)
    if self.is_middle:
      identity = self.conv_shortcut(identity)
      x = x + identity
    return x

class UpsampleResidualBlock(nn.Module):
  """
  Residual block used in both encoder and decoder.
  """
  def __init__(self, in_channels, out_channels, is_middle=False):
    super().__init__()
    self.is_middle = is_middle
    # Calculate num_groups based on in_channels to ensure divisibility
    num_groups = min(32, in_channels)
    self.conv1 = nn.Sequential(
        nn.GroupNorm(num_groups, in_channels), # Use calculated num_groups
        nn.SiLU(),
        nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, padding=0, stride=2),
        nn.Dropout(0.01)
    )
    # Calculate num_groups based on out_channels to ensure divisibility
    num_groups = min(32, out_channels)
    self.conv2 = nn.Sequential(
        nn.GroupNorm(num_groups, out_channels), # Use calculated num_groups
        nn.SiLU(),
        nn.ConvTranspose2d(out_channels, out_channels, kernel_size=2, padding=0, stride=2),
        nn.Dropout(0.01)
    )
    if is_middle:
        self.conv_shortcut = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    self.initialize_weights()

  def initialize_weights(self):
    # Initialize conv layers with kaiming_normal
    for m in self.modules():
        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.GroupNorm):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0)
    # Zero-initialize the last conv layer in each residual block
    nn.init.constant_(self.conv2[-2].weight, 0)
    if self.is_middle:
        nn.init.constant_(self.conv_shortcut.weight, 0)

  def forward(self, x):
    identity = x
    x = self.conv1(x)
    x = self.conv2(x)
    if self.is_middle:
      identity = self.conv_shortcut(identity)
      x = x + identity
    return x

class DownsampleBlock(nn.Module):
  """
  Downsample block with residual autoencoding.
  """
  def __init__(self, in_channels, out_channels, scale=2):
    super().__init__()
    self.residual_block = DownsampleResidualBlock(in_channels, out_channels)
    self.scale = scale
    self.channel_avg = nn.AvgPool2d(kernel_size=scale)
    self.initialize_weights()

  def initialize_weights(self):
        # Zero-initialize the channel_avg layer
        if isinstance(self.channel_avg, nn.AvgPool2d):
            for m in self.channel_avg.modules():
                if isinstance(m, nn.Conv2d):
                    nn.init.constant_(m.weight, 0)
                    if m.bias is not None:
                        nn.init.constant_(m.bias, 0)

  def forward(self, x):
    shortcut = space_to_channel(x, self.scale)
    shortcut = self.channel_avg(shortcut)
    x = self.residual_block(x)
    return x + shortcut

class UpsampleBlock(nn.Module):
  """
  Upsample block with residual autoencoding.
  """
  def __init__(self, in_channels, out_channels, scale=2):
    super().__init__()
    self.residual_block = UpsampleResidualBlock(in_channels, out_channels)
    self.scale = scale
    self.channel_dup = nn.Upsample(scale_factor=scale, mode='nearest')

  def forward(self, x):
    shortcut = channel_to_space(x, self.scale)
    shortcut = self.channel_dup(shortcut)
    x = self.residual_block(x)
    return x + shortcut

class Encoder(nn.Module):
  def __init__(self, in_channels=3, latent_channels=16, channels=[16, 32], scales=[2, 2]):
    super().__init__()
    self.init_conv = nn.Conv2d(in_channels, channels[0], kernel_size=3, padding=1)
    self.downsample_blocks = nn.ModuleList([
        DownsampleBlock(channels[i], channels[i+1], scale=scales[i]) for i in range(len(channels)-1)
    ])
    self.middle_stage = nn.Sequential(
        ResidualBlock(channels[-1], channels[-1], is_middle=True),
        ResidualBlock(channels[-1], latent_channels, is_middle=True),
    )
    self.middle_shortcut = nn.Sequential(
        nn.GroupNorm(32, channels[-1]),
        nn.SiLU(),
        nn.Conv2d(channels[-1], latent_channels, kernel_size=3, padding=1),
        nn.Dropout(0.05)
    )
    self.initialize_weights()

  def initialize_weights(self):
    # Initialize init_conv layer with kaiming_normal
    nn.init.kaiming_normal_(self.init_conv.weight, mode='fan_out', nonlinearity='relu')
    if self.init_conv.bias is not None:
        nn.init.constant_(self.init_conv.bias, 0)

    # Initialize middle_shortcut layers with kaiming_normal
    for m in self.middle_shortcut.modules():
        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.GroupNorm):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0)

  def forward(self, x):
    x = self.init_conv(x)
    for block in self.downsample_blocks:
      x = block(x)
    middle = self.middle_stage(x)
    middle_shortcut = self.middle_shortcut(x)
    x = middle + middle_shortcut
    return x

class Decoder(nn.Module):
  def __init__(self, out_channels=3, latent_channels=16, channels=[32, 16], scales=[2, 2]):
    super().__init__()
    self.middle_stage = nn.Sequential(
        ResidualBlock(latent_channels, channels[0], is_middle=True),
        ResidualBlock(channels[0], channels[0], is_middle=True),
    )
    num_groups = min(32, latent_channels)
    self.middle_shortcut = nn.Sequential(
        nn.GroupNorm(num_groups, latent_channels),
        nn.SiLU(),
        nn.Conv2d(latent_channels, channels[0], kernel_size=3, padding=1),
        nn.Dropout(0.01)
    )
    self.upsample_blocks = nn.ModuleList([
        UpsampleBlock(channels[i], channels[i+1], scale=scales[i]) for i in range(len(channels)-1)
    ])
    self.final_conv = nn.Sequential(
        nn.GroupNorm(8, channels[-1]),
        nn.SiLU(),
        nn.Conv2d(channels[-1], out_channels, kernel_size=3, padding=1),
    )
    self.initialize_weights()

  def initialize_weights(self):
        # Initialize final_conv layers with kaiming_normal
        for m in self.final_conv.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.GroupNorm):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)

  def forward(self, x):
    middle = self.middle_stage(x)
    middle_shortcut = self.middle_shortcut(x)
    x = middle + middle_shortcut
    for block in self.upsample_blocks:
      x = block(x)
    x = self.final_conv(x)
    return x

class DCAE(nn.Module):
    def __init__(self, in_channels=3, out_channels=3, latent_channels=16, encoder_channels=[16, 32, 64], decoder_channels=[64, 32, 16], scales=[2, 2, 2]):
        super().__init__()
        self.encoder = Encoder(in_channels, latent_channels, encoder_channels, scales)
        self.decoder = Decoder(out_channels, latent_channels, decoder_channels, scales)

    def forward(self, x):
        z = self.encoder(x)
        x_recon = self.decoder(z)
        return x_recon

# Example usage:
model = DCAE(
    in_channels=3,
    out_channels=3,
    latent_channels=16,
    encoder_channels=[16, 32],  # Reduced channels
    decoder_channels=[32, 16],  # Reduced channels
    scales=[2, 2]  # f8 compression: 32 / (2*2*2) = 4
)

model.to(device)
# Out:
# DCAE(
#   (encoder): Encoder(
#     (init_conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (downsample_blocks): ModuleList(
#       (0): DownsampleBlock(
#         (residual_block): DownsampleResidualBlock(
#           (conv1): Sequential(
#             (0): GroupNorm(16, 16, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#             (3): Dropout(p=0.01, inplace=False)
#           )
#           (conv2): Sequential(
#             (0): GroupNorm(32, 32, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#             (3): Dropout(p=0.01, inplace=False)
#           )
#         )
#         (channel_avg): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#     )
#     (middle_stage): Sequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 32, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (3): Dropout(p=0.01, inplace=False)
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 32, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (3): Dropout(p=0.01, inplace=False)
#         )
#         (conv_shortcut): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 32, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (3): Dropout(p=0.01, inplace=False)
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(16, 16, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (3): Dropout(p=0.01, inplace=False)
#         )
#         (conv_shortcut): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (middle_shortcut): Sequential(
#       (0): GroupNorm(32, 32, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): Dropout(p=0.05, inplace=False)
#     )
#   )
#   (decoder): Decoder(
#     (middle_stage): Sequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(16, 16, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (3): Dropout(p=0.01, inplace=False)
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 32, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (3): Dropout(p=0.01, inplace=False)
#         )
#         (conv_shortcut): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 32, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (3): Dropout(p=0.01, inplace=False)
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 32, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (3): Dropout(p=0.01, inplace=False)
#         )
#         (conv_shortcut): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (middle_shortcut): Sequential(
#       (0): GroupNorm(16, 16, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): Dropout(p=0.01, inplace=False)
#     )
#     (upsample_blocks): ModuleList(
#       (0): UpsampleBlock(
#         (residual_block): UpsampleResidualBlock(
#           (conv1): Sequential(
#             (0): GroupNorm(32, 32, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): ConvTranspose2d(32, 16, kernel_size=(2, 2), stride=(2, 2))
#             (3): Dropout(p=0.01, inplace=False)
#           )
#           (conv2): Sequential(
#             (0): GroupNorm(16, 16, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): ConvTranspose2d(16, 16, kernel_size=(2, 2), stride=(2, 2))
#             (3): Dropout(p=0.01, inplace=False)
#           )
#         )
#         (channel_dup): Upsample(scale_factor=2.0, mode='nearest')
#       )
#     )
#     (final_conv): Sequential(
#       (0): GroupNorm(8, 16, eps=1e-05, affine=True)
#       (1): SiLU()
#       (2): Conv2d(16, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
# )

# %%
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# Transformations
transform = transforms.Compose([
    transforms.ToTensor(),  # Converts to tensor and scales to [0, 1]
    # If you want to use Phase 3 (GAN), consider normalizing to [-1, 1]
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Dataset
train_dataset = torchvision.datasets.STL10(root='./data', split='unlabeled', download=True, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=512, shuffle=True)
# Out:
# Downloading http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz to ./data/stl10_binary.tar.gz
# 100%|██████████| 2.64G/2.64G [01:57<00:00, 22.5MB/s]
# Extracting ./data/stl10_binary.tar.gz to ./data

# %%
from pytorch_optimizer import create_optimizer

optimizer = create_optimizer(
    model,
    'soap',
    lr=5e-4,
    weight_decay=0.01,
    betas=(.95, .95),
    precondition_frequency=10
)

criterion = nn.L1Loss()  # Or L1Loss, or LPIPS if you have it implemented

# %%
# Training Loop (Phase 1)
num_epochs = 40
for epoch in range(num_epochs):
    for batch_idx, (data, _) in enumerate(train_loader):
        data = data.to(device)
        optimizer.zero_grad()
        recon_batch = model(data)
        loss = criterion(recon_batch, data)
        loss.backward()
        optimizer.step()

        if batch_idx % 10 == 0:
            print(f'Epoch: {epoch+1}/{num_epochs}, Batch: {batch_idx+1}/{len(train_loader)}, Loss: {loss.item():.4f}')
# Out:
# Epoch: 1/40, Batch: 1/196, Loss: 1.3425
# Epoch: 1/40, Batch: 11/196, Loss: 1.0849
# Epoch: 1/40, Batch: 21/196, Loss: 0.8909
# Epoch: 1/40, Batch: 31/196, Loss: 0.7519
# Epoch: 1/40, Batch: 41/196, Loss: 0.6427
# Epoch: 1/40, Batch: 51/196, Loss: 0.5564
# Epoch: 1/40, Batch: 61/196, Loss: 0.4880
# Epoch: 1/40, Batch: 71/196, Loss: 0.4415
# Epoch: 1/40, Batch: 81/196, Loss: 0.4012
# Epoch: 1/40, Batch: 91/196, Loss: 0.3692
# Epoch: 1/40, Batch: 101/196, Loss: 0.3446
# Epoch: 1/40, Batch: 111/196, Loss: 0.3335
# Epoch: 1/40, Batch: 121/196, Loss: 0.3113
# Epoch: 1/40, Batch: 131/196, Loss: 0.3029
# Epoch: 1/40, Batch: 141/196, Loss: 0.2838
# Epoch: 1/40, Batch: 151/196, Loss: 0.2733
# Epoch: 1/40, Batch: 161/196, Loss: 0.2627
# Epoch: 1/40, Batch: 171/196, Loss: 0.2506
# Epoch: 1/40, Batch: 181/196, Loss: 0.2408
# Epoch: 1/40, Batch: 191/196, Loss: 0.2332
# Epoch: 2/40, Batch: 1/196, Loss: 0.2180
# Epoch: 2/40, Batch: 11/196, Loss: 0.2195
# Epoch: 2/40, Batch: 21/196, Loss: 0.2063
# Epoch: 2/40, Batch: 31/196, Loss: 0.1974
# Epoch: 2/40, Batch: 41/196, Loss: 0.1959
# Epoch: 2/40, Batch: 51/196, Loss: 0.1894
# Epoch: 2/40, Batch: 61/196, Loss: 0.1781
# Epoch: 2/40, Batch: 71/196, Loss: 0.1769
# Epoch: 2/40, Batch: 81/196, Loss: 0.1695
# Epoch: 2/40, Batch: 91/196, Loss: 0.1689
# Epoch: 2/40, Batch: 101/196, Loss: 0.1609
# Epoch: 2/40, Batch: 111/196, Loss: 0.1598
# Epoch: 2/40, Batch: 121/196, Loss: 0.1561
# Epoch: 2/40, Batch: 131/196, Loss: 0.1515
# Epoch: 2/40, Batch: 141/196, Loss: 0.1471
# Epoch: 2/40, Batch: 151/196, Loss: 0.1419
# Epoch: 2/40, Batch: 161/196, Loss: 0.1369
# Epoch: 2/40, Batch: 171/196, Loss: 0.1361
# Epoch: 2/40, Batch: 181/196, Loss: 0.1342
# Epoch: 2/40, Batch: 191/196, Loss: 0.1323
# Epoch: 3/40, Batch: 1/196, Loss: 0.1307
# Epoch: 3/40, Batch: 11/196, Loss: 0.1246
# Epoch: 3/40, Batch: 21/196, Loss: 0.1227
# Epoch: 3/40, Batch: 31/196, Loss: 0.1220
# Epoch: 3/40, Batch: 41/196, Loss: 0.1204
# Epoch: 3/40, Batch: 51/196, Loss: 0.1175
# Epoch: 3/40, Batch: 61/196, Loss: 0.1154
# Epoch: 3/40, Batch: 71/196, Loss: 0.1162
# Epoch: 3/40, Batch: 81/196, Loss: 0.1155
# Epoch: 3/40, Batch: 91/196, Loss: 0.1120
# Epoch: 3/40, Batch: 101/196, Loss: 0.1115
# Epoch: 3/40, Batch: 111/196, Loss: 0.1111
# Epoch: 3/40, Batch: 121/196, Loss: 0.1080
# Epoch: 3/40, Batch: 131/196, Loss: 0.1087
# Epoch: 3/40, Batch: 141/196, Loss: 0.1077
# Epoch: 3/40, Batch: 151/196, Loss: 0.1086
# Epoch: 3/40, Batch: 161/196, Loss: 0.1041
# Epoch: 3/40, Batch: 171/196, Loss: 0.1061
# Epoch: 3/40, Batch: 181/196, Loss: 0.1027
# Epoch: 3/40, Batch: 191/196, Loss: 0.1039
# Epoch: 4/40, Batch: 1/196, Loss: 0.1022
# Epoch: 4/40, Batch: 11/196, Loss: 0.1018
# Epoch: 4/40, Batch: 21/196, Loss: 0.1006
# Epoch: 4/40, Batch: 31/196, Loss: 0.1002
# Epoch: 4/40, Batch: 41/196, Loss: 0.0965
# Epoch: 4/40, Batch: 51/196, Loss: 0.0989
# Epoch: 4/40, Batch: 61/196, Loss: 0.0959
# Epoch: 4/40, Batch: 71/196, Loss: 0.0966
# Epoch: 4/40, Batch: 81/196, Loss: 0.0978
# Epoch: 4/40, Batch: 91/196, Loss: 0.0969
# Epoch: 4/40, Batch: 101/196, Loss: 0.0950
# Epoch: 4/40, Batch: 111/196, Loss: 0.0924
# Epoch: 4/40, Batch: 121/196, Loss: 0.0956
# Epoch: 4/40, Batch: 131/196, Loss: 0.0952
# Epoch: 4/40, Batch: 141/196, Loss: 0.0912
# Epoch: 4/40, Batch: 151/196, Loss: 0.0922
# Epoch: 4/40, Batch: 161/196, Loss: 0.0941
# Epoch: 4/40, Batch: 171/196, Loss: 0.0947
# Epoch: 4/40, Batch: 181/196, Loss: 0.0912
# Epoch: 4/40, Batch: 191/196, Loss: 0.0914
# Epoch: 5/40, Batch: 1/196, Loss: 0.0918
# Epoch: 5/40, Batch: 11/196, Loss: 0.0909
# Epoch: 5/40, Batch: 21/196, Loss: 0.0904
# Epoch: 5/40, Batch: 31/196, Loss: 0.0900
# Epoch: 5/40, Batch: 41/196, Loss: 0.0894
# Epoch: 5/40, Batch: 51/196, Loss: 0.0895
# Epoch: 5/40, Batch: 61/196, Loss: 0.0881
# Epoch: 5/40, Batch: 71/196, Loss: 0.0880
# Epoch: 5/40, Batch: 81/196, Loss: 0.0861
# Epoch: 5/40, Batch: 91/196, Loss: 0.0897
# Epoch: 5/40, Batch: 101/196, Loss: 0.0872
# Epoch: 5/40, Batch: 111/196, Loss: 0.0884
# Epoch: 5/40, Batch: 121/196, Loss: 0.0866
# Epoch: 5/40, Batch: 131/196, Loss: 0.0869
# Epoch: 5/40, Batch: 141/196, Loss: 0.0866
# Epoch: 5/40, Batch: 151/196, Loss: 0.0873
# Epoch: 5/40, Batch: 161/196, Loss: 0.0854
# Epoch: 5/40, Batch: 171/196, Loss: 0.0836
# Epoch: 5/40, Batch: 181/196, Loss: 0.0840
# Epoch: 5/40, Batch: 191/196, Loss: 0.0835
# Epoch: 6/40, Batch: 1/196, Loss: 0.0863
# Epoch: 6/40, Batch: 11/196, Loss: 0.0831
# Epoch: 6/40, Batch: 21/196, Loss: 0.0844
# Epoch: 6/40, Batch: 31/196, Loss: 0.0837
# Epoch: 6/40, Batch: 41/196, Loss: 0.0831
# Epoch: 6/40, Batch: 51/196, Loss: 0.0849
# Epoch: 6/40, Batch: 61/196, Loss: 0.0830
# Epoch: 6/40, Batch: 71/196, Loss: 0.0829
# Epoch: 6/40, Batch: 81/196, Loss: 0.0837
# Epoch: 6/40, Batch: 91/196, Loss: 0.0824
# Epoch: 6/40, Batch: 101/196, Loss: 0.0814
# Epoch: 6/40, Batch: 111/196, Loss: 0.0820
# Epoch: 6/40, Batch: 121/196, Loss: 0.0811
# Epoch: 6/40, Batch: 131/196, Loss: 0.0830
# Epoch: 6/40, Batch: 141/196, Loss: 0.0815
# Epoch: 6/40, Batch: 151/196, Loss: 0.0802
# Epoch: 6/40, Batch: 161/196, Loss: 0.0821
# Epoch: 6/40, Batch: 171/196, Loss: 0.0808
# Epoch: 6/40, Batch: 181/196, Loss: 0.0799
# Epoch: 6/40, Batch: 191/196, Loss: 0.0821
# Epoch: 7/40, Batch: 1/196, Loss: 0.0805
# Epoch: 7/40, Batch: 11/196, Loss: 0.0787
# Epoch: 7/40, Batch: 21/196, Loss: 0.0813
# Epoch: 7/40, Batch: 31/196, Loss: 0.0808
# Epoch: 7/40, Batch: 41/196, Loss: 0.0796
# Epoch: 7/40, Batch: 51/196, Loss: 0.0793
# Epoch: 7/40, Batch: 61/196, Loss: 0.0804
# Epoch: 7/40, Batch: 71/196, Loss: 0.0798
# Epoch: 7/40, Batch: 81/196, Loss: 0.0796
# Epoch: 7/40, Batch: 91/196, Loss: 0.0796
# Epoch: 7/40, Batch: 101/196, Loss: 0.0766
# Epoch: 7/40, Batch: 111/196, Loss: 0.0794
# Epoch: 7/40, Batch: 121/196, Loss: 0.0784
# Epoch: 7/40, Batch: 131/196, Loss: 0.0788
# Epoch: 7/40, Batch: 141/196, Loss: 0.0798
# Epoch: 7/40, Batch: 151/196, Loss: 0.0785
# Epoch: 7/40, Batch: 161/196, Loss: 0.0785
# Epoch: 7/40, Batch: 171/196, Loss: 0.0779
# Epoch: 7/40, Batch: 181/196, Loss: 0.0777
# Epoch: 7/40, Batch: 191/196, Loss: 0.0770
# Epoch: 8/40, Batch: 1/196, Loss: 0.0768
# Epoch: 8/40, Batch: 11/196, Loss: 0.0776
# Epoch: 8/40, Batch: 21/196, Loss: 0.0760
# Epoch: 8/40, Batch: 31/196, Loss: 0.0780
# Epoch: 8/40, Batch: 41/196, Loss: 0.0767
# Epoch: 8/40, Batch: 51/196, Loss: 0.0780
# Epoch: 8/40, Batch: 61/196, Loss: 0.0787
# Epoch: 8/40, Batch: 71/196, Loss: 0.0787
# Epoch: 8/40, Batch: 81/196, Loss: 0.0784
# Epoch: 8/40, Batch: 91/196, Loss: 0.0778
# Epoch: 8/40, Batch: 101/196, Loss: 0.0762
# Epoch: 8/40, Batch: 111/196, Loss: 0.0771
# Epoch: 8/40, Batch: 121/196, Loss: 0.0767
# Epoch: 8/40, Batch: 131/196, Loss: 0.0771
# Epoch: 8/40, Batch: 141/196, Loss: 0.0762
# Epoch: 8/40, Batch: 151/196, Loss: 0.0758
# Epoch: 8/40, Batch: 161/196, Loss: 0.0762
# Epoch: 8/40, Batch: 171/196, Loss: 0.0762
# Epoch: 8/40, Batch: 181/196, Loss: 0.0763
# Epoch: 8/40, Batch: 191/196, Loss: 0.0764
# Epoch: 9/40, Batch: 1/196, Loss: 0.0765
# Epoch: 9/40, Batch: 11/196, Loss: 0.0752
# Epoch: 9/40, Batch: 21/196, Loss: 0.0745
# Epoch: 9/40, Batch: 31/196, Loss: 0.0746
# Epoch: 9/40, Batch: 41/196, Loss: 0.0747
# Epoch: 9/40, Batch: 51/196, Loss: 0.0755
# Epoch: 9/40, Batch: 61/196, Loss: 0.0745
# Epoch: 9/40, Batch: 71/196, Loss: 0.0750
# Epoch: 9/40, Batch: 81/196, Loss: 0.0776
# Epoch: 9/40, Batch: 91/196, Loss: 0.0742
# Epoch: 9/40, Batch: 101/196, Loss: 0.0751
# Epoch: 9/40, Batch: 111/196, Loss: 0.0744
# Epoch: 9/40, Batch: 121/196, Loss: 0.0742
# Epoch: 9/40, Batch: 131/196, Loss: 0.0741
# Epoch: 9/40, Batch: 141/196, Loss: 0.0746
# Epoch: 9/40, Batch: 151/196, Loss: 0.0749
# Epoch: 9/40, Batch: 161/196, Loss: 0.0732
# Epoch: 9/40, Batch: 171/196, Loss: 0.0729
# Epoch: 9/40, Batch: 181/196, Loss: 0.0734
# Epoch: 9/40, Batch: 191/196, Loss: 0.0736
# Epoch: 10/40, Batch: 1/196, Loss: 0.0760
# Epoch: 10/40, Batch: 11/196, Loss: 0.0739
# Epoch: 10/40, Batch: 21/196, Loss: 0.0736
# Epoch: 10/40, Batch: 31/196, Loss: 0.0737
# Epoch: 10/40, Batch: 41/196, Loss: 0.0749
# Epoch: 10/40, Batch: 51/196, Loss: 0.0735
# Epoch: 10/40, Batch: 61/196, Loss: 0.0741
# Epoch: 10/40, Batch: 71/196, Loss: 0.0731
# Epoch: 10/40, Batch: 81/196, Loss: 0.0741
# Epoch: 10/40, Batch: 91/196, Loss: 0.0728
# Epoch: 10/40, Batch: 101/196, Loss: 0.0725
# Epoch: 10/40, Batch: 111/196, Loss: 0.0743
# Epoch: 10/40, Batch: 121/196, Loss: 0.0732
# Epoch: 10/40, Batch: 131/196, Loss: 0.0733
# Epoch: 10/40, Batch: 141/196, Loss: 0.0731
# Epoch: 10/40, Batch: 151/196, Loss: 0.0722
# Epoch: 10/40, Batch: 161/196, Loss: 0.0729
# Epoch: 10/40, Batch: 171/196, Loss: 0.0723
# Epoch: 10/40, Batch: 181/196, Loss: 0.0728
# Epoch: 10/40, Batch: 191/196, Loss: 0.0735
# Epoch: 11/40, Batch: 1/196, Loss: 0.0715
# Epoch: 11/40, Batch: 11/196, Loss: 0.0730
# Epoch: 11/40, Batch: 21/196, Loss: 0.0719
# Epoch: 11/40, Batch: 31/196, Loss: 0.0710
# Epoch: 11/40, Batch: 41/196, Loss: 0.0711
# Epoch: 11/40, Batch: 51/196, Loss: 0.0721
# Epoch: 11/40, Batch: 61/196, Loss: 0.0714
# Epoch: 11/40, Batch: 71/196, Loss: 0.0709
# Epoch: 11/40, Batch: 81/196, Loss: 0.0716
# Epoch: 11/40, Batch: 91/196, Loss: 0.0728
# Epoch: 11/40, Batch: 101/196, Loss: 0.0721
# Epoch: 11/40, Batch: 111/196, Loss: 0.0711
# Epoch: 11/40, Batch: 121/196, Loss: 0.0706
# Epoch: 11/40, Batch: 131/196, Loss: 0.0715
# Epoch: 11/40, Batch: 141/196, Loss: 0.0715
# Epoch: 11/40, Batch: 151/196, Loss: 0.0719
# Epoch: 11/40, Batch: 161/196, Loss: 0.0706
# Epoch: 11/40, Batch: 171/196, Loss: 0.0712
# Epoch: 11/40, Batch: 181/196, Loss: 0.0728
# Epoch: 11/40, Batch: 191/196, Loss: 0.0709
# Epoch: 12/40, Batch: 1/196, Loss: 0.0709
# Epoch: 12/40, Batch: 11/196, Loss: 0.0715
# Epoch: 12/40, Batch: 21/196, Loss: 0.0704
# Epoch: 12/40, Batch: 31/196, Loss: 0.0714
# Epoch: 12/40, Batch: 41/196, Loss: 0.0718
# Epoch: 12/40, Batch: 51/196, Loss: 0.0711
# Epoch: 12/40, Batch: 61/196, Loss: 0.0713
# Epoch: 12/40, Batch: 71/196, Loss: 0.0712
# Epoch: 12/40, Batch: 81/196, Loss: 0.0722
# Epoch: 12/40, Batch: 91/196, Loss: 0.0708
# Epoch: 12/40, Batch: 101/196, Loss: 0.0716
# Epoch: 12/40, Batch: 111/196, Loss: 0.0708
# Epoch: 12/40, Batch: 121/196, Loss: 0.0702
# Epoch: 12/40, Batch: 131/196, Loss: 0.0706
# Epoch: 12/40, Batch: 141/196, Loss: 0.0702
# Epoch: 12/40, Batch: 151/196, Loss: 0.0695
# Epoch: 12/40, Batch: 161/196, Loss: 0.0707
# Epoch: 12/40, Batch: 171/196, Loss: 0.0709
# Epoch: 12/40, Batch: 181/196, Loss: 0.0700
# Epoch: 12/40, Batch: 191/196, Loss: 0.0688
# Epoch: 13/40, Batch: 1/196, Loss: 0.0712
# Epoch: 13/40, Batch: 11/196, Loss: 0.0704
# Epoch: 13/40, Batch: 21/196, Loss: 0.0700
# Epoch: 13/40, Batch: 31/196, Loss: 0.0696
# Epoch: 13/40, Batch: 41/196, Loss: 0.0691
# Epoch: 13/40, Batch: 51/196, Loss: 0.0704
# Epoch: 13/40, Batch: 61/196, Loss: 0.0704
# Epoch: 13/40, Batch: 71/196, Loss: 0.0691
# Epoch: 13/40, Batch: 81/196, Loss: 0.0699
# Epoch: 13/40, Batch: 91/196, Loss: 0.0695
# Epoch: 13/40, Batch: 101/196, Loss: 0.0705
# Epoch: 13/40, Batch: 111/196, Loss: 0.0694
# Epoch: 13/40, Batch: 121/196, Loss: 0.0699
# Epoch: 13/40, Batch: 131/196, Loss: 0.0696
# Epoch: 13/40, Batch: 141/196, Loss: 0.0699
# Epoch: 13/40, Batch: 151/196, Loss: 0.0705
# Epoch: 13/40, Batch: 161/196, Loss: 0.0689
# Epoch: 13/40, Batch: 171/196, Loss: 0.0701
# Epoch: 13/40, Batch: 181/196, Loss: 0.0701
# Epoch: 13/40, Batch: 191/196, Loss: 0.0691
# Epoch: 14/40, Batch: 1/196, Loss: 0.0678
# Epoch: 14/40, Batch: 11/196, Loss: 0.0683
# Epoch: 14/40, Batch: 21/196, Loss: 0.0697
# Epoch: 14/40, Batch: 31/196, Loss: 0.0693
# Epoch: 14/40, Batch: 41/196, Loss: 0.0686
# Epoch: 14/40, Batch: 51/196, Loss: 0.0683
# Epoch: 14/40, Batch: 61/196, Loss: 0.0686
# Epoch: 14/40, Batch: 71/196, Loss: 0.0692
# Epoch: 14/40, Batch: 81/196, Loss: 0.0690
# Epoch: 14/40, Batch: 91/196, Loss: 0.0679
# Epoch: 14/40, Batch: 101/196, Loss: 0.0691
# Epoch: 14/40, Batch: 111/196, Loss: 0.0685
# Epoch: 14/40, Batch: 121/196, Loss: 0.0693
# Epoch: 14/40, Batch: 131/196, Loss: 0.0685
# Epoch: 14/40, Batch: 141/196, Loss: 0.0670
# Epoch: 14/40, Batch: 151/196, Loss: 0.0686
# Epoch: 14/40, Batch: 161/196, Loss: 0.0678
# Epoch: 14/40, Batch: 171/196, Loss: 0.0694
# Epoch: 14/40, Batch: 181/196, Loss: 0.0693
# Epoch: 14/40, Batch: 191/196, Loss: 0.0692
# Epoch: 15/40, Batch: 1/196, Loss: 0.0705
# Epoch: 15/40, Batch: 11/196, Loss: 0.0680
# Epoch: 15/40, Batch: 21/196, Loss: 0.0685
# Epoch: 15/40, Batch: 31/196, Loss: 0.0693
# Epoch: 15/40, Batch: 41/196, Loss: 0.0684
# Epoch: 15/40, Batch: 51/196, Loss: 0.0703
# Epoch: 15/40, Batch: 61/196, Loss: 0.0691
# Epoch: 15/40, Batch: 71/196, Loss: 0.0683
# Epoch: 15/40, Batch: 81/196, Loss: 0.0678
# Epoch: 15/40, Batch: 91/196, Loss: 0.0698
# Epoch: 15/40, Batch: 101/196, Loss: 0.0673
# Epoch: 15/40, Batch: 111/196, Loss: 0.0677
# Epoch: 15/40, Batch: 121/196, Loss: 0.0674
# Epoch: 15/40, Batch: 131/196, Loss: 0.0691
# Epoch: 15/40, Batch: 151/196, Loss: 0.0678
# Epoch: 15/40, Batch: 161/196, Loss: 0.0680
# Epoch: 15/40, Batch: 171/196, Loss: 0.0675
# Epoch: 15/40, Batch: 181/196, Loss: 0.0674
# Epoch: 15/40, Batch: 191/196, Loss: 0.0662
# Epoch: 16/40, Batch: 1/196, Loss: 0.0678
# Epoch: 16/40, Batch: 11/196, Loss: 0.0669
# Epoch: 16/40, Batch: 21/196, Loss: 0.0678
# Epoch: 16/40, Batch: 31/196, Loss: 0.0665
# Epoch: 16/40, Batch: 41/196, Loss: 0.0678
# Epoch: 16/40, Batch: 51/196, Loss: 0.0676
# Epoch: 16/40, Batch: 61/196, Loss: 0.0674
# Epoch: 16/40, Batch: 71/196, Loss: 0.0663
# Epoch: 16/40, Batch: 81/196, Loss: 0.0675
# Epoch: 16/40, Batch: 91/196, Loss: 0.0691
# Epoch: 16/40, Batch: 101/196, Loss: 0.0677
# Epoch: 16/40, Batch: 111/196, Loss: 0.0680
# Epoch: 16/40, Batch: 121/196, Loss: 0.0680
# Epoch: 16/40, Batch: 131/196, Loss: 0.0675
# Epoch: 16/40, Batch: 141/196, Loss: 0.0689
# Epoch: 16/40, Batch: 151/196, Loss: 0.0686
# Epoch: 16/40, Batch: 161/196, Loss: 0.0661
# Epoch: 16/40, Batch: 171/196, Loss: 0.0685
# Epoch: 16/40, Batch: 181/196, Loss: 0.0684
# Epoch: 16/40, Batch: 191/196, Loss: 0.0678
# Epoch: 17/40, Batch: 1/196, Loss: 0.0674
# Epoch: 17/40, Batch: 11/196, Loss: 0.0673
# Epoch: 17/40, Batch: 21/196, Loss: 0.0670
# Epoch: 17/40, Batch: 31/196, Loss: 0.0676
# Epoch: 17/40, Batch: 41/196, Loss: 0.0663
# Epoch: 17/40, Batch: 51/196, Loss: 0.0671
# Epoch: 17/40, Batch: 61/196, Loss: 0.0673
# Epoch: 17/40, Batch: 71/196, Loss: 0.0671
# Epoch: 17/40, Batch: 81/196, Loss: 0.0669
# Epoch: 17/40, Batch: 91/196, Loss: 0.0678
# Epoch: 17/40, Batch: 101/196, Loss: 0.0681
# Epoch: 17/40, Batch: 111/196, Loss: 0.0662
# Epoch: 17/40, Batch: 121/196, Loss: 0.0663
# Epoch: 17/40, Batch: 131/196, Loss: 0.0675
# Epoch: 17/40, Batch: 141/196, Loss: 0.0664
# Epoch: 17/40, Batch: 151/196, Loss: 0.0658
# Epoch: 17/40, Batch: 161/196, Loss: 0.0669
# Epoch: 17/40, Batch: 171/196, Loss: 0.0671
# Epoch: 17/40, Batch: 181/196, Loss: 0.0670
# Epoch: 17/40, Batch: 191/196, Loss: 0.0670
# Epoch: 18/40, Batch: 1/196, Loss: 0.0673
# Epoch: 18/40, Batch: 11/196, Loss: 0.0671
# Epoch: 18/40, Batch: 21/196, Loss: 0.0684
# Epoch: 18/40, Batch: 31/196, Loss: 0.0649
# Epoch: 18/40, Batch: 41/196, Loss: 0.0670
# Epoch: 18/40, Batch: 51/196, Loss: 0.0671
# Epoch: 18/40, Batch: 61/196, Loss: 0.0674
# Epoch: 18/40, Batch: 71/196, Loss: 0.0667
# Epoch: 18/40, Batch: 81/196, Loss: 0.0666
# Epoch: 18/40, Batch: 91/196, Loss: 0.0670
# Epoch: 18/40, Batch: 101/196, Loss: 0.0659
# Epoch: 18/40, Batch: 111/196, Loss: 0.0671
# Epoch: 18/40, Batch: 121/196, Loss: 0.0667
# Epoch: 18/40, Batch: 131/196, Loss: 0.0680
# Epoch: 18/40, Batch: 141/196, Loss: 0.0650
# Epoch: 18/40, Batch: 151/196, Loss: 0.0663
# Epoch: 18/40, Batch: 161/196, Loss: 0.0661
# Epoch: 18/40, Batch: 171/196, Loss: 0.0658
# Epoch: 18/40, Batch: 181/196, Loss: 0.0660
# Epoch: 18/40, Batch: 191/196, Loss: 0.0667
# Epoch: 19/40, Batch: 1/196, Loss: 0.0658
# Epoch: 19/40, Batch: 11/196, Loss: 0.0664
# Epoch: 19/40, Batch: 21/196, Loss: 0.0681
# Epoch: 19/40, Batch: 31/196, Loss: 0.0671
# Epoch: 19/40, Batch: 41/196, Loss: 0.0668
# Epoch: 19/40, Batch: 51/196, Loss: 0.0666
# Epoch: 19/40, Batch: 61/196, Loss: 0.0667
# Epoch: 19/40, Batch: 71/196, Loss: 0.0659
# Epoch: 19/40, Batch: 81/196, Loss: 0.0659
# Epoch: 19/40, Batch: 91/196, Loss: 0.0654
# Epoch: 19/40, Batch: 101/196, Loss: 0.0654
# Epoch: 19/40, Batch: 111/196, Loss: 0.0664
# Epoch: 19/40, Batch: 121/196, Loss: 0.0666
# Epoch: 19/40, Batch: 131/196, Loss: 0.0656
# Epoch: 19/40, Batch: 141/196, Loss: 0.0651
# Epoch: 19/40, Batch: 151/196, Loss: 0.0660
# Epoch: 19/40, Batch: 161/196, Loss: 0.0655
# Epoch: 19/40, Batch: 171/196, Loss: 0.0666
# Epoch: 19/40, Batch: 181/196, Loss: 0.0650
# Epoch: 19/40, Batch: 191/196, Loss: 0.0657
# Epoch: 20/40, Batch: 1/196, Loss: 0.0655
# Epoch: 20/40, Batch: 11/196, Loss: 0.0664
# Epoch: 20/40, Batch: 21/196, Loss: 0.0658
# Epoch: 20/40, Batch: 31/196, Loss: 0.0660
# Epoch: 20/40, Batch: 41/196, Loss: 0.0652
# Epoch: 20/40, Batch: 51/196, Loss: 0.0664
# Epoch: 20/40, Batch: 61/196, Loss: 0.0666
# Epoch: 20/40, Batch: 71/196, Loss: 0.0656
# Epoch: 20/40, Batch: 81/196, Loss: 0.0659
# Epoch: 20/40, Batch: 91/196, Loss: 0.0670
# Epoch: 20/40, Batch: 101/196, Loss: 0.0651
# Epoch: 20/40, Batch: 111/196, Loss: 0.0661
# Epoch: 20/40, Batch: 121/196, Loss: 0.0662
# Epoch: 20/40, Batch: 131/196, Loss: 0.0647
# Epoch: 20/40, Batch: 141/196, Loss: 0.0657
# Epoch: 20/40, Batch: 151/196, Loss: 0.0656
# Epoch: 20/40, Batch: 161/196, Loss: 0.0637
# Epoch: 20/40, Batch: 171/196, Loss: 0.0651
# Epoch: 20/40, Batch: 181/196, Loss: 0.0661
# Epoch: 20/40, Batch: 191/196, Loss: 0.0649
# Epoch: 21/40, Batch: 1/196, Loss: 0.0649
# Epoch: 21/40, Batch: 11/196, Loss: 0.0656
# Epoch: 21/40, Batch: 21/196, Loss: 0.0640
# Epoch: 21/40, Batch: 31/196, Loss: 0.0666
# Epoch: 21/40, Batch: 41/196, Loss: 0.0657
# Epoch: 21/40, Batch: 51/196, Loss: 0.0662
# Epoch: 21/40, Batch: 61/196, Loss: 0.0649
# Epoch: 21/40, Batch: 71/196, Loss: 0.0660
# Epoch: 21/40, Batch: 81/196, Loss: 0.0643
# Epoch: 21/40, Batch: 91/196, Loss: 0.0660
# Epoch: 21/40, Batch: 101/196, Loss: 0.0660
# Epoch: 21/40, Batch: 111/196, Loss: 0.0654
# Epoch: 21/40, Batch: 121/196, Loss: 0.0657
# Epoch: 21/40, Batch: 131/196, Loss: 0.0651
# Epoch: 21/40, Batch: 141/196, Loss: 0.0657
# Epoch: 21/40, Batch: 151/196, Loss: 0.0663
# Epoch: 21/40, Batch: 161/196, Loss: 0.0670
# Epoch: 21/40, Batch: 171/196, Loss: 0.0643
# Epoch: 21/40, Batch: 181/196, Loss: 0.0651
# Epoch: 21/40, Batch: 191/196, Loss: 0.0651
# Epoch: 22/40, Batch: 1/196, Loss: 0.0654
# Epoch: 22/40, Batch: 11/196, Loss: 0.0659
# Epoch: 22/40, Batch: 21/196, Loss: 0.0637
# Epoch: 22/40, Batch: 31/196, Loss: 0.0649
# Epoch: 22/40, Batch: 41/196, Loss: 0.0639
# Epoch: 22/40, Batch: 51/196, Loss: 0.0656
# Epoch: 22/40, Batch: 61/196, Loss: 0.0653
# Epoch: 22/40, Batch: 71/196, Loss: 0.0646
# Epoch: 22/40, Batch: 81/196, Loss: 0.0658
# Epoch: 22/40, Batch: 91/196, Loss: 0.0652
# Epoch: 22/40, Batch: 101/196, Loss: 0.0648
# Epoch: 22/40, Batch: 111/196, Loss: 0.0642
# Epoch: 22/40, Batch: 121/196, Loss: 0.0648
# Epoch: 22/40, Batch: 131/196, Loss: 0.0657
# Epoch: 22/40, Batch: 141/196, Loss: 0.0648
# Epoch: 22/40, Batch: 151/196, Loss: 0.0665
# Epoch: 22/40, Batch: 161/196, Loss: 0.0647
# Epoch: 22/40, Batch: 171/196, Loss: 0.0640
# Epoch: 22/40, Batch: 181/196, Loss: 0.0650
# Epoch: 22/40, Batch: 191/196, Loss: 0.0640
# Epoch: 23/40, Batch: 11/196, Loss: 0.0648
# Epoch: 23/40, Batch: 21/196, Loss: 0.0649
# Epoch: 23/40, Batch: 31/196, Loss: 0.0653
# Epoch: 23/40, Batch: 41/196, Loss: 0.0632
# Epoch: 23/40, Batch: 51/196, Loss: 0.0644
# Epoch: 23/40, Batch: 61/196, Loss: 0.0640
# Epoch: 23/40, Batch: 71/196, Loss: 0.0646
# Epoch: 23/40, Batch: 81/196, Loss: 0.0641
# Epoch: 23/40, Batch: 91/196, Loss: 0.0640
# Epoch: 23/40, Batch: 101/196, Loss: 0.0640
# Epoch: 23/40, Batch: 111/196, Loss: 0.0643
# Epoch: 23/40, Batch: 121/196, Loss: 0.0655
# Epoch: 23/40, Batch: 131/196, Loss: 0.0646
# Epoch: 23/40, Batch: 141/196, Loss: 0.0648
# Epoch: 23/40, Batch: 151/196, Loss: 0.0641
# Epoch: 23/40, Batch: 161/196, Loss: 0.0645
# Epoch: 23/40, Batch: 171/196, Loss: 0.0637
# Epoch: 23/40, Batch: 181/196, Loss: 0.0641
# Epoch: 23/40, Batch: 191/196, Loss: 0.0652
# Epoch: 24/40, Batch: 1/196, Loss: 0.0640
# Epoch: 24/40, Batch: 11/196, Loss: 0.0628
# Epoch: 24/40, Batch: 21/196, Loss: 0.0644
# Epoch: 24/40, Batch: 31/196, Loss: 0.0633
# Epoch: 24/40, Batch: 41/196, Loss: 0.0652
# Epoch: 24/40, Batch: 51/196, Loss: 0.0645
# Epoch: 24/40, Batch: 61/196, Loss: 0.0656
# Epoch: 24/40, Batch: 71/196, Loss: 0.0630
# Epoch: 24/40, Batch: 81/196, Loss: 0.0645
# Epoch: 24/40, Batch: 91/196, Loss: 0.0637
# Epoch: 24/40, Batch: 101/196, Loss: 0.0637
# Epoch: 24/40, Batch: 111/196, Loss: 0.0645
# Epoch: 24/40, Batch: 121/196, Loss: 0.0649
# Epoch: 24/40, Batch: 131/196, Loss: 0.0645
# Epoch: 24/40, Batch: 141/196, Loss: 0.0638
# Epoch: 24/40, Batch: 151/196, Loss: 0.0649
# Epoch: 24/40, Batch: 161/196, Loss: 0.0639
# Epoch: 24/40, Batch: 171/196, Loss: 0.0633
# Epoch: 24/40, Batch: 181/196, Loss: 0.0646
# Epoch: 24/40, Batch: 191/196, Loss: 0.0625
# Epoch: 25/40, Batch: 1/196, Loss: 0.0647
# Epoch: 25/40, Batch: 11/196, Loss: 0.0643
# Epoch: 25/40, Batch: 21/196, Loss: 0.0633
# Epoch: 25/40, Batch: 31/196, Loss: 0.0653
# Epoch: 25/40, Batch: 41/196, Loss: 0.0634
# Epoch: 25/40, Batch: 51/196, Loss: 0.0643
# Epoch: 25/40, Batch: 61/196, Loss: 0.0632
# Epoch: 25/40, Batch: 71/196, Loss: 0.0646
# Epoch: 25/40, Batch: 81/196, Loss: 0.0647
# Epoch: 25/40, Batch: 91/196, Loss: 0.0624
# Epoch: 25/40, Batch: 101/196, Loss: 0.0638
# Epoch: 25/40, Batch: 111/196, Loss: 0.0638
# Epoch: 25/40, Batch: 121/196, Loss: 0.0656
# Epoch: 25/40, Batch: 131/196, Loss: 0.0643
# Epoch: 25/40, Batch: 141/196, Loss: 0.0635
# Epoch: 25/40, Batch: 151/196, Loss: 0.0637
# Epoch: 25/40, Batch: 161/196, Loss: 0.0633
# Epoch: 25/40, Batch: 171/196, Loss: 0.0621
# Epoch: 25/40, Batch: 181/196, Loss: 0.0626
# Epoch: 25/40, Batch: 191/196, Loss: 0.0641
# Epoch: 26/40, Batch: 1/196, Loss: 0.0637
# Epoch: 26/40, Batch: 11/196, Loss: 0.0633
# Epoch: 26/40, Batch: 21/196, Loss: 0.0648
# Epoch: 26/40, Batch: 31/196, Loss: 0.0629
# Epoch: 26/40, Batch: 41/196, Loss: 0.0634
# Epoch: 26/40, Batch: 51/196, Loss: 0.0640
# Epoch: 26/40, Batch: 61/196, Loss: 0.0627
# Epoch: 26/40, Batch: 71/196, Loss: 0.0639
# Epoch: 26/40, Batch: 81/196, Loss: 0.0645
# Epoch: 26/40, Batch: 91/196, Loss: 0.0613
# Epoch: 26/40, Batch: 101/196, Loss: 0.0647
# Epoch: 26/40, Batch: 111/196, Loss: 0.0626
# Epoch: 26/40, Batch: 121/196, Loss: 0.0630
# Epoch: 26/40, Batch: 131/196, Loss: 0.0632
# Epoch: 26/40, Batch: 141/196, Loss: 0.0636
# Epoch: 26/40, Batch: 151/196, Loss: 0.0631
# Epoch: 26/40, Batch: 161/196, Loss: 0.0643
# Epoch: 26/40, Batch: 171/196, Loss: 0.0632
# Epoch: 26/40, Batch: 181/196, Loss: 0.0637
# Epoch: 26/40, Batch: 191/196, Loss: 0.0643
# Epoch: 27/40, Batch: 1/196, Loss: 0.0631
# Epoch: 27/40, Batch: 11/196, Loss: 0.0628
# Epoch: 27/40, Batch: 21/196, Loss: 0.0638
# Epoch: 27/40, Batch: 31/196, Loss: 0.0633
# Epoch: 27/40, Batch: 41/196, Loss: 0.0635
# Epoch: 27/40, Batch: 51/196, Loss: 0.0635
# Epoch: 27/40, Batch: 61/196, Loss: 0.0640
# Epoch: 27/40, Batch: 71/196, Loss: 0.0639
# Epoch: 27/40, Batch: 81/196, Loss: 0.0634
# Epoch: 27/40, Batch: 91/196, Loss: 0.0626
# Epoch: 27/40, Batch: 101/196, Loss: 0.0638
# Epoch: 27/40, Batch: 111/196, Loss: 0.0643
# Epoch: 27/40, Batch: 121/196, Loss: 0.0635
# Epoch: 27/40, Batch: 131/196, Loss: 0.0643
# Epoch: 27/40, Batch: 141/196, Loss: 0.0630
# Epoch: 27/40, Batch: 151/196, Loss: 0.0636
# Epoch: 27/40, Batch: 161/196, Loss: 0.0625
# Epoch: 27/40, Batch: 171/196, Loss: 0.0622
# Epoch: 27/40, Batch: 181/196, Loss: 0.0631
# Epoch: 27/40, Batch: 191/196, Loss: 0.0624
# Epoch: 28/40, Batch: 1/196, Loss: 0.0624
# Epoch: 28/40, Batch: 11/196, Loss: 0.0633
# Epoch: 28/40, Batch: 21/196, Loss: 0.0621
# Epoch: 28/40, Batch: 31/196, Loss: 0.0635
# Epoch: 28/40, Batch: 41/196, Loss: 0.0632
# Epoch: 28/40, Batch: 51/196, Loss: 0.0614
# Epoch: 28/40, Batch: 61/196, Loss: 0.0634
# Epoch: 28/40, Batch: 71/196, Loss: 0.0612
# Epoch: 28/40, Batch: 81/196, Loss: 0.0640
# Epoch: 28/40, Batch: 91/196, Loss: 0.0627
# Epoch: 28/40, Batch: 101/196, Loss: 0.0638
# Epoch: 28/40, Batch: 111/196, Loss: 0.0623
# Epoch: 28/40, Batch: 121/196, Loss: 0.0622
# Epoch: 28/40, Batch: 131/196, Loss: 0.0628
# Epoch: 28/40, Batch: 141/196, Loss: 0.0623
# Epoch: 28/40, Batch: 151/196, Loss: 0.0626
# Epoch: 28/40, Batch: 161/196, Loss: 0.0627
# Epoch: 28/40, Batch: 171/196, Loss: 0.0625
# Epoch: 28/40, Batch: 181/196, Loss: 0.0635
# Epoch: 28/40, Batch: 191/196, Loss: 0.0623
# Epoch: 29/40, Batch: 1/196, Loss: 0.0635
# Epoch: 29/40, Batch: 11/196, Loss: 0.0633
# Epoch: 29/40, Batch: 21/196, Loss: 0.0643
# Epoch: 29/40, Batch: 31/196, Loss: 0.0622
# Epoch: 29/40, Batch: 41/196, Loss: 0.0618
# Epoch: 29/40, Batch: 51/196, Loss: 0.0632
# Epoch: 29/40, Batch: 61/196, Loss: 0.0629
# Epoch: 29/40, Batch: 71/196, Loss: 0.0631
# Epoch: 29/40, Batch: 81/196, Loss: 0.0622
# Epoch: 29/40, Batch: 91/196, Loss: 0.0615
# Epoch: 29/40, Batch: 101/196, Loss: 0.0606
# Epoch: 29/40, Batch: 111/196, Loss: 0.0615
# Epoch: 29/40, Batch: 121/196, Loss: 0.0634
# Epoch: 29/40, Batch: 131/196, Loss: 0.0624
# Epoch: 29/40, Batch: 141/196, Loss: 0.0632
# Epoch: 29/40, Batch: 151/196, Loss: 0.0623
# Epoch: 29/40, Batch: 161/196, Loss: 0.0626
# Epoch: 29/40, Batch: 171/196, Loss: 0.0630
# Epoch: 29/40, Batch: 181/196, Loss: 0.0632
# Epoch: 29/40, Batch: 191/196, Loss: 0.0639
# Epoch: 30/40, Batch: 1/196, Loss: 0.0638
# Epoch: 30/40, Batch: 11/196, Loss: 0.0637
# Epoch: 30/40, Batch: 21/196, Loss: 0.0614
# Epoch: 30/40, Batch: 31/196, Loss: 0.0614
# Epoch: 30/40, Batch: 41/196, Loss: 0.0625
# Epoch: 30/40, Batch: 51/196, Loss: 0.0628
# Epoch: 30/40, Batch: 61/196, Loss: 0.0618
# Epoch: 30/40, Batch: 71/196, Loss: 0.0621
# Epoch: 30/40, Batch: 81/196, Loss: 0.0624
# Epoch: 30/40, Batch: 91/196, Loss: 0.0631
# Epoch: 30/40, Batch: 101/196, Loss: 0.0627
# Epoch: 30/40, Batch: 111/196, Loss: 0.0633
# Epoch: 30/40, Batch: 121/196, Loss: 0.0620
# Epoch: 30/40, Batch: 131/196, Loss: 0.0623
# Epoch: 30/40, Batch: 141/196, Loss: 0.0636
# Epoch: 30/40, Batch: 151/196, Loss: 0.0620
# Epoch: 30/40, Batch: 161/196, Loss: 0.0617
# Epoch: 30/40, Batch: 171/196, Loss: 0.0622
# Epoch: 30/40, Batch: 181/196, Loss: 0.0612
# Epoch: 30/40, Batch: 191/196, Loss: 0.0643
# Epoch: 31/40, Batch: 1/196, Loss: 0.0614
# Epoch: 31/40, Batch: 11/196, Loss: 0.0614
# Epoch: 31/40, Batch: 21/196, Loss: 0.0603
# Epoch: 31/40, Batch: 31/196, Loss: 0.0623
# Epoch: 31/40, Batch: 41/196, Loss: 0.0615
# Epoch: 31/40, Batch: 51/196, Loss: 0.0626
# Epoch: 31/40, Batch: 61/196, Loss: 0.0617
# Epoch: 31/40, Batch: 71/196, Loss: 0.0615
# Epoch: 31/40, Batch: 81/196, Loss: 0.0630
# Epoch: 31/40, Batch: 91/196, Loss: 0.0613
# Epoch: 31/40, Batch: 101/196, Loss: 0.0622
# Epoch: 31/40, Batch: 111/196, Loss: 0.0624
# Epoch: 31/40, Batch: 121/196, Loss: 0.0612
# Epoch: 31/40, Batch: 131/196, Loss: 0.0628
# Epoch: 31/40, Batch: 141/196, Loss: 0.0609
# Epoch: 31/40, Batch: 151/196, Loss: 0.0610
# Epoch: 31/40, Batch: 161/196, Loss: 0.0627
# Epoch: 31/40, Batch: 171/196, Loss: 0.0626
# Epoch: 31/40, Batch: 181/196, Loss: 0.0614
# Epoch: 31/40, Batch: 191/196, Loss: 0.0608
# Epoch: 32/40, Batch: 1/196, Loss: 0.0618
# Epoch: 32/40, Batch: 11/196, Loss: 0.0616
# Epoch: 32/40, Batch: 21/196, Loss: 0.0630
# Epoch: 32/40, Batch: 31/196, Loss: 0.0613
# Epoch: 32/40, Batch: 41/196, Loss: 0.0621
# Epoch: 32/40, Batch: 51/196, Loss: 0.0626
# Epoch: 32/40, Batch: 61/196, Loss: 0.0622
# Epoch: 32/40, Batch: 71/196, Loss: 0.0623
# Epoch: 32/40, Batch: 81/196, Loss: 0.0613
# Epoch: 32/40, Batch: 91/196, Loss: 0.0635
# Epoch: 32/40, Batch: 101/196, Loss: 0.0607
# Epoch: 32/40, Batch: 111/196, Loss: 0.0630
# Epoch: 32/40, Batch: 121/196, Loss: 0.0629
# Epoch: 32/40, Batch: 131/196, Loss: 0.0614
# Epoch: 32/40, Batch: 141/196, Loss: 0.0614
# Epoch: 32/40, Batch: 151/196, Loss: 0.0620
# Epoch: 32/40, Batch: 161/196, Loss: 0.0619
# Epoch: 32/40, Batch: 171/196, Loss: 0.0621
# Epoch: 32/40, Batch: 181/196, Loss: 0.0617
# Epoch: 32/40, Batch: 191/196, Loss: 0.0623
# Epoch: 33/40, Batch: 1/196, Loss: 0.0624
# Epoch: 33/40, Batch: 11/196, Loss: 0.0616
# Epoch: 33/40, Batch: 21/196, Loss: 0.0635
# Epoch: 33/40, Batch: 31/196, Loss: 0.0621
# Epoch: 33/40, Batch: 41/196, Loss: 0.0617
# Epoch: 33/40, Batch: 51/196, Loss: 0.0616
# Epoch: 33/40, Batch: 61/196, Loss: 0.0612
# Epoch: 33/40, Batch: 71/196, Loss: 0.0614
# Epoch: 33/40, Batch: 81/196, Loss: 0.0621
# Epoch: 33/40, Batch: 91/196, Loss: 0.0617
# Epoch: 33/40, Batch: 101/196, Loss: 0.0616
# Epoch: 33/40, Batch: 111/196, Loss: 0.0614
# Epoch: 33/40, Batch: 121/196, Loss: 0.0618
# Epoch: 33/40, Batch: 131/196, Loss: 0.0609
# Epoch: 33/40, Batch: 141/196, Loss: 0.0612
# Epoch: 33/40, Batch: 151/196, Loss: 0.0612
# Epoch: 33/40, Batch: 161/196, Loss: 0.0607
# Epoch: 33/40, Batch: 171/196, Loss: 0.0614
# Epoch: 33/40, Batch: 181/196, Loss: 0.0611
# Epoch: 33/40, Batch: 191/196, Loss: 0.0596
# Epoch: 34/40, Batch: 1/196, Loss: 0.0604
# Epoch: 34/40, Batch: 11/196, Loss: 0.0619
# Epoch: 34/40, Batch: 21/196, Loss: 0.0612
# Epoch: 34/40, Batch: 31/196, Loss: 0.0619
# Epoch: 34/40, Batch: 41/196, Loss: 0.0624
# Epoch: 34/40, Batch: 51/196, Loss: 0.0620
# Epoch: 34/40, Batch: 61/196, Loss: 0.0616
# Epoch: 34/40, Batch: 71/196, Loss: 0.0600
# Epoch: 34/40, Batch: 81/196, Loss: 0.0609
# Epoch: 34/40, Batch: 91/196, Loss: 0.0607
# Epoch: 34/40, Batch: 111/196, Loss: 0.0615
# Epoch: 34/40, Batch: 121/196, Loss: 0.0622
# Epoch: 34/40, Batch: 131/196, Loss: 0.0612
# Epoch: 34/40, Batch: 141/196, Loss: 0.0616
# Epoch: 34/40, Batch: 151/196, Loss: 0.0615
# Epoch: 34/40, Batch: 161/196, Loss: 0.0613
# Epoch: 34/40, Batch: 171/196, Loss: 0.0618
# Epoch: 34/40, Batch: 181/196, Loss: 0.0612
# Epoch: 34/40, Batch: 191/196, Loss: 0.0614
# Epoch: 35/40, Batch: 1/196, Loss: 0.0605
# Epoch: 35/40, Batch: 11/196, Loss: 0.0635
# Epoch: 35/40, Batch: 21/196, Loss: 0.0614
# Epoch: 35/40, Batch: 31/196, Loss: 0.0608
# Epoch: 35/40, Batch: 41/196, Loss: 0.0615
# Epoch: 35/40, Batch: 51/196, Loss: 0.0614
# Epoch: 35/40, Batch: 61/196, Loss: 0.0607
# Epoch: 35/40, Batch: 71/196, Loss: 0.0617
# Epoch: 35/40, Batch: 81/196, Loss: 0.0617
# Epoch: 35/40, Batch: 91/196, Loss: 0.0604
# Epoch: 35/40, Batch: 101/196, Loss: 0.0612
# Epoch: 35/40, Batch: 111/196, Loss: 0.0612
# Epoch: 35/40, Batch: 121/196, Loss: 0.0612
# Epoch: 35/40, Batch: 131/196, Loss: 0.0617
# Epoch: 35/40, Batch: 141/196, Loss: 0.0604
# Epoch: 35/40, Batch: 151/196, Loss: 0.0615
# Epoch: 35/40, Batch: 161/196, Loss: 0.0616
# Epoch: 35/40, Batch: 171/196, Loss: 0.0612
# Epoch: 35/40, Batch: 181/196, Loss: 0.0613
# Epoch: 35/40, Batch: 191/196, Loss: 0.0613
# Epoch: 36/40, Batch: 1/196, Loss: 0.0608
# Epoch: 36/40, Batch: 11/196, Loss: 0.0615
# Epoch: 36/40, Batch: 21/196, Loss: 0.0605
# Epoch: 36/40, Batch: 31/196, Loss: 0.0618
# Epoch: 36/40, Batch: 41/196, Loss: 0.0610
# Epoch: 36/40, Batch: 51/196, Loss: 0.0606
# Epoch: 36/40, Batch: 61/196, Loss: 0.0595
# Epoch: 36/40, Batch: 71/196, Loss: 0.0616
# Epoch: 36/40, Batch: 81/196, Loss: 0.0608
# Epoch: 36/40, Batch: 91/196, Loss: 0.0620
# Epoch: 36/40, Batch: 101/196, Loss: 0.0610
# Epoch: 36/40, Batch: 111/196, Loss: 0.0615
# Epoch: 36/40, Batch: 121/196, Loss: 0.0608
# Epoch: 36/40, Batch: 131/196, Loss: 0.0608
# Epoch: 36/40, Batch: 141/196, Loss: 0.0610
# Epoch: 36/40, Batch: 151/196, Loss: 0.0606
# Epoch: 36/40, Batch: 161/196, Loss: 0.0611
# Epoch: 36/40, Batch: 171/196, Loss: 0.0617
# Epoch: 36/40, Batch: 181/196, Loss: 0.0618
# Epoch: 36/40, Batch: 191/196, Loss: 0.0610
# Epoch: 37/40, Batch: 1/196, Loss: 0.0601
# Epoch: 37/40, Batch: 11/196, Loss: 0.0608
# Epoch: 37/40, Batch: 21/196, Loss: 0.0612
# Epoch: 37/40, Batch: 31/196, Loss: 0.0601
# Epoch: 37/40, Batch: 41/196, Loss: 0.0609
# Epoch: 37/40, Batch: 51/196, Loss: 0.0604
# Epoch: 37/40, Batch: 61/196, Loss: 0.0605
# Epoch: 37/40, Batch: 71/196, Loss: 0.0624
# Epoch: 37/40, Batch: 81/196, Loss: 0.0613
# Epoch: 37/40, Batch: 91/196, Loss: 0.0613
# Epoch: 37/40, Batch: 101/196, Loss: 0.0604
# Epoch: 37/40, Batch: 111/196, Loss: 0.0615
# Epoch: 37/40, Batch: 121/196, Loss: 0.0613
# Epoch: 37/40, Batch: 131/196, Loss: 0.0621
# Epoch: 37/40, Batch: 141/196, Loss: 0.0607
# Epoch: 37/40, Batch: 151/196, Loss: 0.0612
# Epoch: 37/40, Batch: 161/196, Loss: 0.0617
# Epoch: 37/40, Batch: 171/196, Loss: 0.0626
# Epoch: 37/40, Batch: 181/196, Loss: 0.0613
# Epoch: 37/40, Batch: 191/196, Loss: 0.0611
# Epoch: 38/40, Batch: 1/196, Loss: 0.0608
# Epoch: 38/40, Batch: 11/196, Loss: 0.0610
# Epoch: 38/40, Batch: 21/196, Loss: 0.0599
# Epoch: 38/40, Batch: 31/196, Loss: 0.0597
# Epoch: 38/40, Batch: 41/196, Loss: 0.0607
# Epoch: 38/40, Batch: 51/196, Loss: 0.0601
# Epoch: 38/40, Batch: 61/196, Loss: 0.0609
# Epoch: 38/40, Batch: 71/196, Loss: 0.0606
# Epoch: 38/40, Batch: 81/196, Loss: 0.0613
# Epoch: 38/40, Batch: 91/196, Loss: 0.0606
# Epoch: 38/40, Batch: 101/196, Loss: 0.0598
# Epoch: 38/40, Batch: 111/196, Loss: 0.0595
# Epoch: 38/40, Batch: 121/196, Loss: 0.0604
# Epoch: 38/40, Batch: 131/196, Loss: 0.0606
# Epoch: 38/40, Batch: 141/196, Loss: 0.0596
# Epoch: 38/40, Batch: 151/196, Loss: 0.0597
# Epoch: 38/40, Batch: 161/196, Loss: 0.0607
# Epoch: 38/40, Batch: 171/196, Loss: 0.0613
# Epoch: 38/40, Batch: 181/196, Loss: 0.0605
# Epoch: 38/40, Batch: 191/196, Loss: 0.0624
# Epoch: 39/40, Batch: 1/196, Loss: 0.0594
# Epoch: 39/40, Batch: 11/196, Loss: 0.0605
# Epoch: 39/40, Batch: 21/196, Loss: 0.0602
# Epoch: 39/40, Batch: 31/196, Loss: 0.0603
# Epoch: 39/40, Batch: 41/196, Loss: 0.0610
# Epoch: 39/40, Batch: 51/196, Loss: 0.0600
# Epoch: 39/40, Batch: 61/196, Loss: 0.0598
# Epoch: 39/40, Batch: 71/196, Loss: 0.0610
# Epoch: 39/40, Batch: 81/196, Loss: 0.0609
# Epoch: 39/40, Batch: 91/196, Loss: 0.0602
# Epoch: 39/40, Batch: 101/196, Loss: 0.0621
# Epoch: 39/40, Batch: 111/196, Loss: 0.0601
# Epoch: 39/40, Batch: 121/196, Loss: 0.0608
# Epoch: 39/40, Batch: 131/196, Loss: 0.0592
# Epoch: 39/40, Batch: 141/196, Loss: 0.0596
# Epoch: 39/40, Batch: 151/196, Loss: 0.0597
# Epoch: 39/40, Batch: 161/196, Loss: 0.0595
# Epoch: 39/40, Batch: 171/196, Loss: 0.0592
# Epoch: 39/40, Batch: 181/196, Loss: 0.0609
# Epoch: 39/40, Batch: 191/196, Loss: 0.0607
# Epoch: 40/40, Batch: 1/196, Loss: 0.0614
# Epoch: 40/40, Batch: 11/196, Loss: 0.0606
# Epoch: 40/40, Batch: 21/196, Loss: 0.0602
# Epoch: 40/40, Batch: 31/196, Loss: 0.0603
# Epoch: 40/40, Batch: 41/196, Loss: 0.0602
# Epoch: 40/40, Batch: 51/196, Loss: 0.0602
# Epoch: 40/40, Batch: 61/196, Loss: 0.0597
# Epoch: 40/40, Batch: 71/196, Loss: 0.0596
# Epoch: 40/40, Batch: 81/196, Loss: 0.0600
# Epoch: 40/40, Batch: 91/196, Loss: 0.0598
# Epoch: 40/40, Batch: 101/196, Loss: 0.0604
# Epoch: 40/40, Batch: 111/196, Loss: 0.0597
# Epoch: 40/40, Batch: 121/196, Loss: 0.0598
# Epoch: 40/40, Batch: 131/196, Loss: 0.0610
# Epoch: 40/40, Batch: 141/196, Loss: 0.0601
# Epoch: 40/40, Batch: 151/196, Loss: 0.0606
# Epoch: 40/40, Batch: 161/196, Loss: 0.0621
# Epoch: 40/40, Batch: 171/196, Loss: 0.0607
# Epoch: 40/40, Batch: 181/196, Loss: 0.0590
# Epoch: 40/40, Batch: 191/196, Loss: 0.0602

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- STL-10 Test Dataset ---
stl10_test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalize if you used normalization during training
])

stl10_test_dataset = torchvision.datasets.STL10(root='./data', split='test', download=True, transform=stl10_test_transform)
stl10_test_loader = DataLoader(stl10_test_dataset, batch_size=1, shuffle=False)  # Batch size 1 for individual image display

# --- Function to Display Images ---
def imshow(img, title=""):
    img = img / 2 + 0.5     # Unnormalize if needed
    img = img.cpu() # Move the tensor to the CPU
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title(title)
    plt.axis('off')

# --- Inference and Visualization ---
num_images_to_show = 10 # You can change this

for i, (data, _) in enumerate(stl10_test_loader):
    if i >= num_images_to_show:
        break

    data = data.to(device)

    # Inference
    with torch.no_grad():
        reconstructed_data = model(data)

    # Display Images
    plt.figure(figsize=(8, 4))

    plt.subplot(1, 2, 1)
    imshow(data.squeeze(0), title="Original Image")

    plt.subplot(1, 2, 2)
    imshow(reconstructed_data.squeeze(0), title="Reconstructed Image")

    plt.show()
# Out:
# Files already downloaded and verified
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
